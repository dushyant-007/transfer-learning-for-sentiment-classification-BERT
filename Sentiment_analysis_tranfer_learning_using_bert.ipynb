# %% [markdown]
# Necessary Imports

# %%
import matplotlib.pyplot as plt
import pandas as pd
import torch
import torch.nn as nn
import numpy as np

# %% [markdown]
# Getting data from data/sentiment_train.csv

# %%
data = pd.read_csv('https://github.com/dushyant-007/transfer-learning-for-sentiment-classification-BERT/raw/main/data/sentiment_train.csv')
print('info of the data \n')
print(data.info())
print('first few rows of the data: \n',data.head())
# Out:
# info of the data
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5668 entries, 0 to 5667
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sentence  5668 non-null   object
#  1   label     5668 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 88.7+ KB
# None
# first few rows of the data:
#                                              sentence  label
# 0    Ok brokeback mountain is such a horrible movie.      0
# 1                 Brokeback Mountain was so awesome.      1
# 2  friday hung out with kelsie and we went and sa...      0
# 3  I am going to start reading the Harry Potter s...      1
# 4       Is it just me, or does Harry Potter suck?...      0

# %% [markdown]
# Above is how the data looks
#
# Now let us work on it a little bit
#
# 1. Make train - test splits.

# %%
from sklearn.model_selection import train_test_split

x_tr , x_te , y_tr, y_te = train_test_split(data['sentence'].values,
                                            data['label'].values,
                                            train_size=0.8,
                                            random_state=1)

x_tr, x_va, y_tr, y_va = train_test_split(x_tr,
                                          y_tr,
                                          train_size=0.8,
                                          random_state=1)

print(f'shape of x_train is {x_tr.shape}')
print(f'shape of x_test is {x_te.shape}')
print(f'shape of x_val is {x_va.shape}')
print(f'shape of y_train is {y_tr.shape}')
print(f'shape of y_test is {y_te.shape}')
print(f'shape of y_validation is {y_va.shape}')
# Out:
# shape of x_train is (3627,)
# shape of x_test is (1134,)
# shape of x_val is (907,)
# shape of y_train is (3627,)
# shape of y_test is (1134,)
# shape of y_validation is (907,)

# %%
from transformers import AutoModel
bert = AutoModel.from_pretrained('bert-base-uncased')
from transformers import BertTokenizerFast
tokenizer = BertTokenizerFast.from_pretrained('bert-base-uncased')
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# Let's see , what should be the padding length. I want to take the median

# %%
len_of_sentences_in_train_data = [len(i.split()) for i in x_tr]
plt.hist(len_of_sentences_in_train_data)
# Out:
# (array([1340.,  700.,  583.,  443.,  188.,  168.,   99.,   22.,   80.,
#            4.]),
#  array([ 3. ,  6.7, 10.4, 14.1, 17.8, 21.5, 25.2, 28.9, 32.6, 36.3, 40. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# From looking at the histogram , I think we should take 15 to be the padding.

# %% [markdown]
# Alright, Now let's tokenize the data.

# %%
pad_len = 15

x_tr_token = tokenizer.batch_encode_plus(
    x_tr.tolist(),
    max_length= pad_len,
    pad_to_max_length = True,
    truncation=True
)

x_va_token = tokenizer.batch_encode_plus(
    x_va.tolist(),
    max_length=pad_len,
    pad_to_max_length = True,
    truncation= True
)

x_te_token = tokenizer.batch_encode_plus(
    x_te.tolist(),
    max_length=pad_len,
    pad_to_max_length = True,
    truncation=True
)

# getting the sequence data
x_tr_seq = torch.tensor(x_tr_token['input_ids'])
x_va_seq = torch.tensor(x_va_token['input_ids'])
x_te_seq = torch.tensor(x_te_token['input_ids'])

# getting the attention mask
x_tr_mask = torch.tensor(x_tr_token['attention_mask'])
x_te_mask = torch.tensor(x_te_token['attention_mask'])
x_va_mask = torch.tensor(x_va_token['attention_mask'])

# getting the labels
y_tr = torch.tensor(y_tr.tolist())
y_va = torch.tensor(y_va.tolist())
y_te = torch.tensor(y_te.tolist())
# Out:
# C:\Users\Dushyant S. Udawat\anaconda3\lib\site-packages\transformers\tokenization_utils_base.py:2304: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(

# %%
print(x_tr_seq)
print(f'the shape of the x_tr_seq is {x_tr_seq.shape}')
# Out:
# tensor([[  101,  1045,  2066,  ...,  1055,  2006,   102],
#         [  101,  1045,  2293,  ...,     0,     0,     0],
#         [  101,  1045,  5223,  ...,  3791,  1037,   102],
#         ...,
#         [  101,  4302, 10693,  ...,  2758, 11543,   102],
#         [  101,  2029,  2003,  ...,  2480,  1045,   102],
#         [  101,  4830, 23765,  ...,     0,     0,     0]])
# the shape of the x_tr_seq is torch.Size([3627, 15])

# %%
print(x_tr[:3])

print(x_tr_seq[:3])
# Out:
# ["I like Mission Impossible movies because you never know who's on the right side."
#  'I love Harry Potter..'
#  'I hate Harry Potter, that daniel wotshisface needs a fucking slap...']
# tensor([[  101,  1045,  2066,  3260,  5263,  5691,  2138,  2017,  2196,  2113,
#           2040,  1005,  1055,  2006,   102],
#         [  101,  1045,  2293,  4302, 10693,  1012,  1012,   102,     0,     0,
#              0,     0,     0,     0,     0],
#         [  101,  1045,  5223,  4302, 10693,  1010,  2008,  3817, 24185,  3215,
#          24158, 12172,  3791,  1037,   102]])

# %% [markdown]
# So, as can be seen the tokenizer just makes the sentence into dictionary indexes. It is nothing special , there is no machine learning here. However, we should remember that the dictionary indexes here are related to their corresponding embeddings in the trained bert model.

# %% [markdown]
# # Defining the model

# %%
for param in bert.parameters():
    param.requires_grad = False

class BERT_arch(nn.Module):
    def __init__(self, bert):
        super(BERT_arch, self).__init__()
        self.bert = bert

        # adding a dropout layer
        self.dropout = nn.Dropout(0.2)

        # relu
        self.relu = nn.ReLU()

        # dense layer 1
        self.fc1 = nn.Linear(768, 512)

        # dense layer 2
        self. fc2 = nn.Linear(512, 2)

        # softmax activation
        self.softmax = nn.LogSoftmax(dim =1 )

    def forward(self, sent_id, mask):
        _, cls_hs = self.bert(sent_id, attention_mask = mask, return_dict = False)

        x = self.fc1(cls_hs)

        x = self.relu(x)

        x = self.dropout(x)

        x = self.fc2(x)

        x = self.softmax(x)

        return x

# %%
from torchsummary import summary

# %%
model = BERT_arch(bert)
optimizer = torch.optim.AdamW(model.parameters(),lr = 1e-5)  # learning rate
print(summary(model=model, input_data=(x_tr_seq[:32, :], x_tr_mask[:32, :])))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─BertModel: 1-1                         [-1, 15, 768]             --
# |    └─BertEmbeddings: 2-1               [-1, 15, 768]             --
# |    |    └─Embedding: 3-1               [-1, 15, 768]             (23,440,896)
# |    |    └─Embedding: 3-2               [-1, 15, 768]             (1,536)
# |    |    └─Embedding: 3-3               [-1, 15, 768]             (393,216)
# |    |    └─LayerNorm: 3-4               [-1, 15, 768]             (1,536)
# |    |    └─Dropout: 3-5                 [-1, 15, 768]             --
# |    └─BertEncoder: 2-2                  [-1, 15, 768]             --
# |    └─BertPooler: 2-3                   [-1, 768]                 --
# |    |    └─Linear: 3-6                  [-1, 768]                 (590,592)
# |    |    └─Tanh: 3-7                    [-1, 768]                 --
# ├─Linear: 1-2                            [-1, 512]                 393,728
# ├─ReLU: 1-3                              [-1, 512]                 --
# ├─Dropout: 1-4                           [-1, 512]                 --
# ├─Linear: 1-5                            [-1, 2]                   1,026
# ├─LogSoftmax: 1-6                        [-1, 2]                   --
# ==========================================================================================
# Total params: 24,822,530
# Trainable params: 394,754
# Non-trainable params: 24,427,776
# Total mult-adds (M): 328.53
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.36
# Params size (MB): 94.69
# Estimated Total Size (MB): 95.06
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─BertModel: 1-1                         [-1, 15, 768]             --
# |    └─BertEmbeddings: 2-1               [-1, 15, 768]             --
# |    |    └─Embedding: 3-1               [-1, 15, 768]             (23,440,896)
# |    |    └─Embedding: 3-2               [-1, 15, 768]             (1,536)
# |    |    └─Embedding: 3-3               [-1, 15, 768]             (393,216)
# |    |    └─LayerNorm: 3-4               [-1, 15, 768]             (1,536)
# |    |    └─Dropout: 3-5                 [-1, 15, 768]             --
# |    └─BertEncoder: 2-2                  [-1, 15, 768]             --
# |    └─BertPooler: 2-3                   [-1, 768]                 --
# |    |    └─Linear: 3-6                  [-1, 768]                 (590,592)
# |    |    └─Tanh: 3-7                    [-1, 768]                 --
# ├─Linear: 1-2                            [-1, 512]                 393,728
# ├─ReLU: 1-3                              [-1, 512]                 --
# ├─Dropout: 1-4                           [-1, 512]                 --
# ├─Linear: 1-5                            [-1, 2]                   1,026
# ├─LogSoftmax: 1-6                        [-1, 2]                   --
# ==========================================================================================
# Total params: 24,822,530
# Trainable params: 394,754
# Non-trainable params: 24,427,776
# Total mult-adds (M): 328.53
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.36
# Params size (MB): 94.69
# Estimated Total Size (MB): 95.06
# ==========================================================================================

# %%
# making the data_loaders here
from torch.utils.data import DataLoader, TensorDataset
batch_size = 256
training_data = TensorDataset(x_tr_seq, x_tr_mask, y_tr)
train_dataloader = DataLoader(training_data, batch_size=batch_size, shuffle=False)
testing_data = TensorDataset(x_te_seq, x_te_mask, y_te)
test_dataloader = DataLoader(testing_data, batch_size=batch_size, shuffle=False)
validation_data = TensorDataset(x_va_seq, x_va_mask, y_va)
val_dataloader = DataLoader(validation_data, batch_size=batch_size, shuffle=False)

# %%
def train(model, train_dataloader, device, loss_fn, optimizer):
    model.train()
    model.to(device)

    losses , accuracy = [], []


    for step , batch in enumerate(train_dataloader):

        
        # pushing to device
        batch = [r.to(device) for r in batch]
        sent_id, mask, labels = batch

        # clear previously calculated gradients
        model.zero_grad()

        # get model predictions for the current batch
        preds = model(sent_id , mask)

        # compute the loss between actual and predicted values
        loss = loss_fn(preds, labels)

        # backward the loss
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        # update the gradients of the model
        optimizer.step()

        # printout the results.
        losses.append(loss.detach().item())
        preds = preds.cpu()
        labels = labels.cpu()
        accuracy.append(sum(preds.detach().argmax(dim=1) == labels))
        #print(f'step - {step}, the loss is {losses[-1]}, accuracy is {accuracy[-1]}')


    return losses, accuracy

# %%
# implementing the evaluate function here.

def evaluate(model, val_dataloader, loss_fn, device):

    print('\nEvaluating ... ')

    model.eval()

    losses, accuracy = [], []

    total_preds = []

    for step, batch in enumerate(val_dataloader):

        # extract the data from the batch
        batch = [r.to(device) for r in batch]
        input_ids, mask, labels = batch


        # pass through the model to produce outputs
        pred = model(input_ids, mask)

        # calculate the loss
        loss = loss_fn(pred, labels)

        #
        losses.append(loss.detach().item())
        pred = pred.cpu()
        labels = labels.cpu()
        accuracy.append(sum(pred.cpu().detach().argmax(dim=1) == labels))
        #print(f'step - {step}, the loss is {losses[-1]}, accuracy is {accuracy[-1]}')

    return losses, accuracy

# %%
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
no_epochs = 150
if not train_loss:
  train_loss, val_loss = [], []
  train_acc, val_acc = [], []
for epoch in range(no_epochs):
  losses , accuracy = train(model, train_dataloader, device, nn.CrossEntropyLoss(), optimizer)
  train_loss.append(sum(losses)/len(losses))
  train_acc.append(sum(accuracy)/len(accuracy)/batch_size)
  print(f'epoch : {epoch}, loss : {train_loss[-1]}, accuracy : {train_acc[-1]}')
  losses_ev, accuracy_ev = evaluate(model, val_dataloader, nn.CrossEntropyLoss(), device)
  val_loss.append(sum(losses_ev)/len(losses_ev))
  val_acc.append(sum(accuracy_ev)/len(accuracy_ev)/batch_size)
  print(f'\t\tepoch : evaluation, loss : {val_loss[-1]}, accuracy : {val_acc[-1]}')
# Out:
# epoch : 0, loss : 0.23587706486384075, accuracy : 0.8804687261581421
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.18115905299782753, accuracy : 0.8505859375
# epoch : 1, loss : 0.240778844555219, accuracy : 0.8776041865348816
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1807681769132614, accuracy : 0.849609375
# epoch : 2, loss : 0.23624376356601715, accuracy : 0.8765624761581421
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.18027178570628166, accuracy : 0.8505859375
# epoch : 3, loss : 0.2355123281478882, accuracy : 0.8770833611488342
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.18074443191289902, accuracy : 0.849609375
# epoch : 4, loss : 0.23615099589029948, accuracy : 0.875
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.17985369637608528, accuracy : 0.8505859375
# epoch : 5, loss : 0.23781247834364574, accuracy : 0.8768228888511658
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.18035541847348213, accuracy : 0.8505859375
# epoch : 6, loss : 0.23508488138516745, accuracy : 0.8773437738418579
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.17814765870571136, accuracy : 0.8515625
# epoch : 7, loss : 0.23580873012542725, accuracy : 0.879687488079071
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.17972182855010033, accuracy : 0.849609375
# epoch : 8, loss : 0.23480375508467358, accuracy : 0.8812500238418579
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.17850999534130096, accuracy : 0.8505859375
# epoch : 9, loss : 0.23485357562700906, accuracy : 0.8736979365348816
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.17745886743068695, accuracy : 0.8515625
# epoch : 10, loss : 0.23026984930038452, accuracy : 0.8851562738418579
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.17712309211492538, accuracy : 0.8505859375
# epoch : 11, loss : 0.2221399982770284, accuracy : 0.8799479007720947
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1789650060236454, accuracy : 0.849609375
# epoch : 12, loss : 0.22205315430959066, accuracy : 0.8848958611488342
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.17581546679139137, accuracy : 0.8515625
# epoch : 13, loss : 0.2337788631518682, accuracy : 0.879687488079071
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.17811815068125725, accuracy : 0.8505859375
# epoch : 14, loss : 0.2279077649116516, accuracy : 0.8825520873069763
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1749156042933464, accuracy : 0.8515625
# epoch : 15, loss : 0.23193941116333008, accuracy : 0.8778645992279053
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.17643330246210098, accuracy : 0.8505859375
# epoch : 16, loss : 0.23262948393821717, accuracy : 0.8794270753860474
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.17390167340636253, accuracy : 0.8515625
# epoch : 17, loss : 0.23251394430796304, accuracy : 0.8765624761581421
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.17555205523967743, accuracy : 0.8505859375
# epoch : 18, loss : 0.22812277774016063, accuracy : 0.8817708492279053
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.173214603215456, accuracy : 0.8515625
# epoch : 19, loss : 0.22740408579508464, accuracy : 0.8822916746139526
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1737578548491001, accuracy : 0.8505859375
# epoch : 20, loss : 0.23541392385959625, accuracy : 0.875781238079071
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.17378563061356544, accuracy : 0.8505859375
# epoch : 21, loss : 0.2221410095691681, accuracy : 0.882031261920929
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1751730553805828, accuracy : 0.8505859375
# epoch : 22, loss : 0.22747406562169392, accuracy : 0.8809896111488342
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.17164190113544464, accuracy : 0.8515625
# epoch : 23, loss : 0.23391291896502178, accuracy : 0.878125011920929
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.17145167291164398, accuracy : 0.8515625
# epoch : 24, loss : 0.23557850917180378, accuracy : 0.8763020634651184
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.17065567150712013, accuracy : 0.8505859375
# epoch : 25, loss : 0.22492644488811492, accuracy : 0.8807291388511658
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.17106595635414124, accuracy : 0.8515625
# epoch : 26, loss : 0.21665335098902386, accuracy : 0.88671875
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.16981161385774612, accuracy : 0.849609375
# epoch : 27, loss : 0.23371186951796213, accuracy : 0.8768228888511658
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1714247204363346, accuracy : 0.8505859375
# epoch : 28, loss : 0.223304283618927, accuracy : 0.8843749761581421
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.16974929347634315, accuracy : 0.8505859375
# epoch : 29, loss : 0.21806925435860952, accuracy : 0.8856770992279053
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.16998165473341942, accuracy : 0.8515625
# epoch : 30, loss : 0.22360146244366963, accuracy : 0.8809896111488342
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.16961653530597687, accuracy : 0.8515625
# epoch : 31, loss : 0.22705655296643576, accuracy : 0.8786458373069763
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.16891338676214218, accuracy : 0.8525390625
# epoch : 32, loss : 0.22317126790682476, accuracy : 0.8825520873069763
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1695421263575554, accuracy : 0.8505859375
# epoch : 33, loss : 0.21732879082361858, accuracy : 0.8825520873069763
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1698872074484825, accuracy : 0.8505859375
# epoch : 34, loss : 0.22042187650998432, accuracy : 0.8828125
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.16799909994006157, accuracy : 0.8525390625
# epoch : 35, loss : 0.21987378398577373, accuracy : 0.8830729126930237
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.16786231473088264, accuracy : 0.8515625
# epoch : 36, loss : 0.22353649536768597, accuracy : 0.8807291388511658
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.16731128469109535, accuracy : 0.8515625
# epoch : 37, loss : 0.2176203002532323, accuracy : 0.8851562738418579
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1659531258046627, accuracy : 0.8515625
# epoch : 38, loss : 0.22011124789714814, accuracy : 0.879687488079071
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1668102629482746, accuracy : 0.8505859375
# epoch : 39, loss : 0.2201097548007965, accuracy : 0.8778645992279053
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.16560739651322365, accuracy : 0.8505859375
# epoch : 40, loss : 0.22656916876633962, accuracy : 0.8807291388511658
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1672930344939232, accuracy : 0.8505859375
# epoch : 41, loss : 0.22117265860239665, accuracy : 0.8848958611488342
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.16497132182121277, accuracy : 0.8505859375
# epoch : 42, loss : 0.2227245420217514, accuracy : 0.8791666626930237
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.16551202535629272, accuracy : 0.8515625
# epoch : 43, loss : 0.211882346868515, accuracy : 0.8856770992279053
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.16582603752613068, accuracy : 0.8505859375
# epoch : 44, loss : 0.22632765273253122, accuracy : 0.8763020634651184
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.16366592049598694, accuracy : 0.8515625
# epoch : 45, loss : 0.2246946821610133, accuracy : 0.8804687261581421
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.16690923273563385, accuracy : 0.8505859375
# epoch : 46, loss : 0.2190050611893336, accuracy : 0.8833333253860474
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1635040007531643, accuracy : 0.8515625
# epoch : 47, loss : 0.2157902757326762, accuracy : 0.883593738079071
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1656397320330143, accuracy : 0.8505859375
# epoch : 48, loss : 0.21849183936913807, accuracy : 0.8856770992279053
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.16287154331803322, accuracy : 0.8515625
# epoch : 49, loss : 0.21329404513041178, accuracy : 0.8861979246139526
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1626257300376892, accuracy : 0.8515625
# epoch : 50, loss : 0.21731368998686473, accuracy : 0.8791666626930237
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1626577451825142, accuracy : 0.8515625
# epoch : 51, loss : 0.2198625942071279, accuracy : 0.8854166865348816
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.16184334456920624, accuracy : 0.8515625
# epoch : 52, loss : 0.21759798129399618, accuracy : 0.8799479007720947
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.16148150712251663, accuracy : 0.8515625
# epoch : 53, loss : 0.2248333215713501, accuracy : 0.8825520873069763
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.16034521162509918, accuracy : 0.8505859375
# epoch : 54, loss : 0.21718057294686635, accuracy : 0.8854166865348816
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.160812109708786, accuracy : 0.8515625
# epoch : 55, loss : 0.21364651719729105, accuracy : 0.8838541507720947
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.16371164470911026, accuracy : 0.8505859375
# epoch : 56, loss : 0.21385526160399118, accuracy : 0.8822916746139526
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1603243499994278, accuracy : 0.8515625
# epoch : 57, loss : 0.21509622236092885, accuracy : 0.8869791626930237
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1607120893895626, accuracy : 0.8505859375
# epoch : 58, loss : 0.21909227470556894, accuracy : 0.8804687261581421
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.16088808327913284, accuracy : 0.8505859375
# epoch : 59, loss : 0.20373787879943847, accuracy : 0.889843761920929
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1599002666771412, accuracy : 0.8515625
# epoch : 60, loss : 0.2188467482725779, accuracy : 0.8828125
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.16032874956727028, accuracy : 0.8505859375
# epoch : 61, loss : 0.2156218002239863, accuracy : 0.8799479007720947
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.15948468074202538, accuracy : 0.8515625
# epoch : 62, loss : 0.21611027618249257, accuracy : 0.8809896111488342
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.15842082351446152, accuracy : 0.8515625
# epoch : 63, loss : 0.20620656112829844, accuracy : 0.8848958611488342
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.16120949760079384, accuracy : 0.8505859375
# epoch : 64, loss : 0.2154933234055837, accuracy : 0.887499988079071
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1578359305858612, accuracy : 0.8515625
# epoch : 65, loss : 0.21299211382865907, accuracy : 0.8848958611488342
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.15847034007310867, accuracy : 0.8505859375
# epoch : 66, loss : 0.2150840739409129, accuracy : 0.882031261920929
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1578681394457817, accuracy : 0.8515625
# epoch : 67, loss : 0.219153160850207, accuracy : 0.8815104365348816
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.15811386331915855, accuracy : 0.8505859375
# epoch : 68, loss : 0.21237120429674786, accuracy : 0.8872395753860474
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.15825103223323822, accuracy : 0.8505859375
# epoch : 69, loss : 0.21167694528897604, accuracy : 0.8794270753860474
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.15658942982554436, accuracy : 0.8515625
# epoch : 70, loss : 0.21477494339148204, accuracy : 0.8830729126930237
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.15633956715464592, accuracy : 0.8515625
# epoch : 71, loss : 0.20872947573661804, accuracy : 0.8843749761581421
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.15621330216526985, accuracy : 0.8515625
# epoch : 72, loss : 0.2160621384779612, accuracy : 0.8817708492279053
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.15502219647169113, accuracy : 0.8515625
# epoch : 73, loss : 0.21167629758516948, accuracy : 0.8825520873069763
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.15665921196341515, accuracy : 0.8505859375
# epoch : 74, loss : 0.2011524607737859, accuracy : 0.890625
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.15495925769209862, accuracy : 0.8515625
# epoch : 75, loss : 0.20677690505981444, accuracy : 0.88671875
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.15472613647580147, accuracy : 0.8515625
# epoch : 76, loss : 0.212586110830307, accuracy : 0.8861979246139526
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.15514150261878967, accuracy : 0.8515625
# epoch : 77, loss : 0.20964624285697936, accuracy : 0.890625
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.15443620830774307, accuracy : 0.8525390625
# epoch : 78, loss : 0.20105218688646953, accuracy : 0.8901041746139526
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1535435989499092, accuracy : 0.8515625
# epoch : 79, loss : 0.20899980664253234, accuracy : 0.8869791626930237
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.15557541698217392, accuracy : 0.8505859375
# epoch : 80, loss : 0.20442304213841755, accuracy : 0.8864583373069763
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.15272566676139832, accuracy : 0.8505859375
# epoch : 81, loss : 0.2040370355049769, accuracy : 0.8882812261581421
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.15266316384077072, accuracy : 0.8515625
# epoch : 82, loss : 0.2075004110733668, accuracy : 0.8864583373069763
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.15093516930937767, accuracy : 0.8515625
# epoch : 83, loss : 0.21124898493289948, accuracy : 0.8828125
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.15167368948459625, accuracy : 0.8515625
# epoch : 84, loss : 0.19589140017827353, accuracy : 0.8885416388511658
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.15109946951270103, accuracy : 0.8515625
# epoch : 85, loss : 0.2108316461245219, accuracy : 0.8848958611488342
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14994924515485764, accuracy : 0.8515625
# epoch : 86, loss : 0.20231595834096272, accuracy : 0.8846353888511658
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.15072719752788544, accuracy : 0.8515625
# epoch : 87, loss : 0.20554493566354115, accuracy : 0.8872395753860474
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.15122408792376518, accuracy : 0.8515625
# epoch : 88, loss : 0.2020919293165207, accuracy : 0.889843761920929
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14933399483561516, accuracy : 0.86328125
# epoch : 89, loss : 0.2109511782725652, accuracy : 0.8822916746139526
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1506805121898651, accuracy : 0.8515625
# epoch : 90, loss : 0.20261967678864798, accuracy : 0.8841145634651184
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1492815837264061, accuracy : 0.8515625
# epoch : 91, loss : 0.20318428575992584, accuracy : 0.88671875
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14961884170770645, accuracy : 0.8505859375
# epoch : 92, loss : 0.20297544797261555, accuracy : 0.8848958611488342
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14759459719061852, accuracy : 0.86328125
# epoch : 93, loss : 0.2000149220228195, accuracy : 0.887499988079071
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1496364213526249, accuracy : 0.8505859375
# epoch : 94, loss : 0.2035822292168935, accuracy : 0.8864583373069763
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14746303483843803, accuracy : 0.8515625
# epoch : 95, loss : 0.2011217753092448, accuracy : 0.8895833492279053
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14717306569218636, accuracy : 0.8515625
# epoch : 96, loss : 0.1939340800046921, accuracy : 0.8901041746139526
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14747587591409683, accuracy : 0.8505859375
# epoch : 97, loss : 0.19811672767003377, accuracy : 0.8888021111488342
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14672879874706268, accuracy : 0.8515625
# epoch : 98, loss : 0.19864182372887929, accuracy : 0.887499988079071
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14604129642248154, accuracy : 0.8515625
# epoch : 99, loss : 0.20335868696371714, accuracy : 0.8838541507720947
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1474306881427765, accuracy : 0.8505859375
# epoch : 100, loss : 0.20289206405480703, accuracy : 0.883593738079071
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14592787250876427, accuracy : 0.8515625
# epoch : 101, loss : 0.19712078074614206, accuracy : 0.887499988079071
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14545810595154762, accuracy : 0.8515625
# epoch : 102, loss : 0.20627225240071614, accuracy : 0.8856770992279053
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14569544047117233, accuracy : 0.8515625
# epoch : 103, loss : 0.19821859101454417, accuracy : 0.8901041746139526
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1444333754479885, accuracy : 0.86328125
# epoch : 104, loss : 0.19601357281208037, accuracy : 0.8856770992279053
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14508596807718277, accuracy : 0.8515625
# epoch : 105, loss : 0.19899610678354898, accuracy : 0.8908854126930237
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14470191299915314, accuracy : 0.8515625
# epoch : 106, loss : 0.19630878567695617, accuracy : 0.8919270634651184
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14433706179261208, accuracy : 0.8515625
# epoch : 107, loss : 0.20198105772336325, accuracy : 0.8919270634651184
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1441301330924034, accuracy : 0.8515625
# epoch : 108, loss : 0.19918666978677113, accuracy : 0.8885416388511658
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14406126365065575, accuracy : 0.8515625
# epoch : 109, loss : 0.19803033272425333, accuracy : 0.889843761920929
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1430208943784237, accuracy : 0.8623046875
# epoch : 110, loss : 0.20213794807593027, accuracy : 0.8877604007720947
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14612946286797523, accuracy : 0.8505859375
# epoch : 111, loss : 0.19576500554879506, accuracy : 0.8872395753860474
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14300275221467018, accuracy : 0.8515625
# epoch : 112, loss : 0.1900764932235082, accuracy : 0.8927083611488342
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14167968556284904, accuracy : 0.86328125
# epoch : 113, loss : 0.1982869654893875, accuracy : 0.8846353888511658
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14416168257594109, accuracy : 0.8505859375
# epoch : 114, loss : 0.20745265583197275, accuracy : 0.8815104365348816
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1432771421968937, accuracy : 0.8505859375
# epoch : 115, loss : 0.20099070072174072, accuracy : 0.8864583373069763
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.140745609998703, accuracy : 0.8623046875
# epoch : 116, loss : 0.19299203256766, accuracy : 0.8885416388511658
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14356108754873276, accuracy : 0.8505859375
# epoch : 117, loss : 0.19016189773877462, accuracy : 0.8911458253860474
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14052150025963783, accuracy : 0.86328125
# epoch : 118, loss : 0.1971762776374817, accuracy : 0.8817708492279053
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14485450461506844, accuracy : 0.849609375
# epoch : 119, loss : 0.1966192732254664, accuracy : 0.88671875
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14076407626271248, accuracy : 0.86328125
# epoch : 120, loss : 0.1922284722328186, accuracy : 0.889843761920929
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1406419463455677, accuracy : 0.8515625
# epoch : 121, loss : 0.1963397055864334, accuracy : 0.8877604007720947
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14045006036758423, accuracy : 0.8515625
# epoch : 122, loss : 0.1970487505197525, accuracy : 0.8815104365348816
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14032823219895363, accuracy : 0.8515625
# epoch : 123, loss : 0.20051412085692089, accuracy : 0.8828125
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1391930803656578, accuracy : 0.86328125
# epoch : 124, loss : 0.1909484287103017, accuracy : 0.890625
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.13970262929797173, accuracy : 0.8515625
# epoch : 125, loss : 0.19992711047331493, accuracy : 0.8854166865348816
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1402767151594162, accuracy : 0.8515625
# epoch : 126, loss : 0.19922396987676622, accuracy : 0.8838541507720947
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14163870736956596, accuracy : 0.849609375
# epoch : 127, loss : 0.19080861310164135, accuracy : 0.8882812261581421
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.14003313705325127, accuracy : 0.8515625
# epoch : 128, loss : 0.19683772325515747, accuracy : 0.88671875
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.13836336508393288, accuracy : 0.86328125
# epoch : 129, loss : 0.19812949895858764, accuracy : 0.8872395753860474
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.13776789605617523, accuracy : 0.8623046875
# epoch : 130, loss : 0.19817174176375071, accuracy : 0.8880208134651184
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.13920369371771812, accuracy : 0.8515625
# epoch : 131, loss : 0.19117566148440043, accuracy : 0.8901041746139526
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.13799742981791496, accuracy : 0.86328125
# epoch : 132, loss : 0.18746664921442668, accuracy : 0.8895833492279053
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1388748362660408, accuracy : 0.8515625
# epoch : 133, loss : 0.186041263739268, accuracy : 0.8921874761581421
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.13680807128548622, accuracy : 0.86328125
# epoch : 134, loss : 0.1912316749493281, accuracy : 0.8908854126930237
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.13637998327612877, accuracy : 0.8623046875
# epoch : 135, loss : 0.18667863607406615, accuracy : 0.8888021111488342
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1380079723894596, accuracy : 0.8505859375
# epoch : 136, loss : 0.18787071506182354, accuracy : 0.887499988079071
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.13614271953701973, accuracy : 0.8515625
# epoch : 137, loss : 0.18070138692855836, accuracy : 0.8880208134651184
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.13557826541364193, accuracy : 0.8623046875
# epoch : 138, loss : 0.18960110346476236, accuracy : 0.887499988079071
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.13581610843539238, accuracy : 0.8515625
# epoch : 139, loss : 0.19062430759270985, accuracy : 0.8864583373069763
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.13536517694592476, accuracy : 0.86328125
# epoch : 140, loss : 0.1896932284037272, accuracy : 0.8895833492279053
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1344937663525343, accuracy : 0.8623046875
# epoch : 141, loss : 0.1840869555870692, accuracy : 0.8932291865348816
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.13457738794386387, accuracy : 0.8623046875
# epoch : 142, loss : 0.1938480188449224, accuracy : 0.8841145634651184
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.13596880435943604, accuracy : 0.8515625
# epoch : 143, loss : 0.1882932096719742, accuracy : 0.8893229365348816
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.13436054438352585, accuracy : 0.86328125
# epoch : 144, loss : 0.18597336411476134, accuracy : 0.8882812261581421
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.13664663583040237, accuracy : 0.8505859375
# epoch : 145, loss : 0.19044734040896097, accuracy : 0.8882812261581421
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.13432783633470535, accuracy : 0.8623046875
# epoch : 146, loss : 0.18356797794500987, accuracy : 0.8947916626930237
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.13276772759854794, accuracy : 0.8623046875
# epoch : 147, loss : 0.1942390779654185, accuracy : 0.8825520873069763
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.13471250236034393, accuracy : 0.8505859375
# epoch : 148, loss : 0.18870983719825746, accuracy : 0.8927083611488342
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.13384241983294487, accuracy : 0.8515625
# epoch : 149, loss : 0.19161223967870075, accuracy : 0.887499988079071
#
# Evaluating ...
# 		epoch : evaluation, loss : 0.1336870901286602, accuracy : 0.86328125

# %%
# lets draw a graph showing epochs 
print(len(train_acc))
no_epochs = len(train_acc)
import matplotlib.pyplot as plt
plt.figure()
plt.title('learning curve - loss vs epoch (training and validation)')
plt.plot(list(range(no_epochs)) , train_loss, 'r', label = 'training loss')
plt.plot(list(range(no_epochs)) , val_loss, 'b', label = 'validation loss')
plt.legend()
plt.show()
# Out:
# 167

# %%
print(len(train_acc))
no_epochs = len(train_acc)
import matplotlib.pyplot as plt
plt.figure()
plt.title('learning curve - accuracy vs epoch (training and validation)')
plt.plot(list(range(no_epochs)) , train_acc, 'r', label = 'training accuracy')
plt.plot(list(range(no_epochs)) , val_acc, 'b', label = 'validation accuracy')
plt.legend()
plt.show()
# Out:
# 167

# %%
# now let's test on new data

with torch.no_grad():
    preds = model(x_te_seq.to(device), x_te_mask.to(device))
    preds = preds.detach().cpu().numpy()

from sklearn.metrics import classification_report
pred = np.argmax(preds, axis =1)
print(classification_report(y_te, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.94      0.96       508
#            1       0.95      0.99      0.97       626
#
#     accuracy                           0.97      1134
#    macro avg       0.97      0.96      0.97      1134
# weighted avg       0.97      0.97      0.97      1134
